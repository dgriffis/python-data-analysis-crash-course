# %% [markdown]
# # Chapter 6 and 7 - Loading data, cleaning and preparation
#
# This notebook is light on the various data loading described in Ch 6, because most of those formats described are all just loaded with various pandas `pd.read_...()` helpers that do all the heavy lifting.  Thats great if you have tabular data.  I am instead going to feed you with a netCDF4 file, which takes a little bit more work to load, but only a few lines.  Ping me if you get stuck.
#
# Grab the data here:
#
# https://data.giss.nasa.gov/pub/gistemp/gistemp250_GHCNv4.nc.gz
#
# I'm not sure if the various options for opening that file (described below) handle the compression, so you probably want to `gzip -d` that file.   This dataset has global temperatures, averaged monthly within 2x2 degree boxes over land (the grid points over the oceans are filled with NaN). The data spans from January 1880 through January 2019, though spatial coverage is sparse at the earlier dates and gets much better with time.
#
# The imports below should cover the various ways to complete the notebook.
#
# ##### Reference
#
# GISTEMP Team, 2019: GISS Surface Temperature Analysis (GISTEMP v4). NASA Goddard Institute for Space Studies. Dataset accessed 2019-03-06 at https://data.giss.nasa.gov/gistemp/.
#
# Hansen, J., R. Ruedy, M. Sato, and K. Lo, 2010: Global surface temperature change, Rev. Geophys., 48, RG4004, doi:10.1029/2010RG000345.

# %%
# You may not need all of these, but you shouldn't need more. YOLO
import pandas as pd
#import netCDF4 as nc4
import xarray as xr
import seaborn as sns
import numpy as np
sns.set()
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
datafile_nc4 = '/Users/dgriffis/code/glg/python-data-analysis-crash-course/data/gistemp250_GHCNv4.nc'

# %% [markdown]
# ### Working with a netCDF4 data file
#
# There are a few ways to go about this, as in anything python related.  Pandas does not speak netCDF by default, but there are some easy ways to get this data into a dataframe.
#
# 1. Load the data with the netCDF4 package and build a dataframe with the variables you are interested in
# 2. Load the data with xarray.open_dataset and convert that to a dataframe with to_dataframe().
#
# There is more in this file than we really need, so if you can get to this state, you win:
#
# ```
# >>> print(df.columns)
#
# Index(['lat', 'lon', 'time', 'tempanomaly'], dtype='object')
# ```

# %%
DS = xr.open_dataset(datafile_nc4)
#DS.values
#DS.var
#DS.dims
#Using DS.coords we can see it as a dict containing three of the of interest keys
#DS.coords
#DS.attrs
df = DS.to_dataframe()
#df = df[:100] 
df = pd.DataFrame(df.to_records())
df = df.drop(['time_bnds','nv'],axis=1)
print(df.columns)
#print(df)
# Out:
# Index(['lat', 'lon', 'time', 'tempanomaly'], dtype='object')

# %% [markdown]
# The lat and lon variables give global coverage every 2 degrees (only odd value of lat and lon) of temperature anomaly (the deviation from the climate average).  Produce a timeseries (data or plot) of the temperature anomaly near Boston, MA. (lat,lon = 43.0, -71.0)

# %%
dataBoston = df.loc[(df['lat'] == 43.0) & (df['lon'] == -71.0)]
dataBoston.plot(x='time', y='tempanomaly');

# %% [markdown]
# Are there any NaN or missing values in this data?

# %%
dataBoston.tempanomaly.isnull().values.any()
# Out:
# False

# %% [markdown]
# Now take a look at the same data at the location (lat,lon = 1.0, -87.0).  Does this data have missing values or NaN?  Are they appropriate?

# %%
myData = df.loc[(df['lat'] == 1.0) & (df['lon'] == -87.0)]
myData.tempanomaly.isnull().values.any()
# Out:
# True

# %%
myData.plot(x='time', y='tempanomaly');

# %% [markdown]
# Now let's focus on a slice of this data in time.  Pick a date in 2018 and all the temperature anomalies and locations associated with that date.  This data is going to come out of pandas, most likely, looking like this:
#
# ```
#            lat    lon  tempanomaly
# 1666     -89.0 -179.0         0.42
# 3335     -89.0 -179.0         0.42
# 5004     -89.0 -177.0         0.42
# ...
# [32400 rows x 3 columns]
# ```
#
# (your data will be different if you chose a different date)
#
# Find the average of the warmest and coolest 10% of the data for the date you chose.

# %%
myTest = df.loc[df['time'] == '2018-09-15'].drop(['time'], axis=1)
coolest = myTest.loc[myTest.tempanomaly <= myTest.tempanomaly.quantile(0.1)]
coolest.describe()
print(coolest.tempanomaly.mean())
# Out:
# -3.2741008

# %%
warmest = myTest.loc[myTest.tempanomaly >= myTest.tempanomaly.quantile(0.9)]
warmest.describe()
print(warmest.tempanomaly.mean())
# Out:
# 3.575602

# %% [markdown]
# #### BONUS!  (I solved this with stuff that turns out was in CH8, but I'm keeping it in)
#
# The last question had data like this:
#
# ```
#            lat    lon  tempanomaly
# 1666     -89.0 -179.0         0.42
# 3335     -89.0 -179.0         0.42
# 5004     -89.0 -177.0         0.42
# ...
# [32400 rows x 3 columns]
# ```
#
# I'm going give you some code to plot a heatmap, but first the data needs to be transformed to look like this:
#
# ```
# lon    -179.0  -177.0  -175.0  -173.0  -171.0  -169.0  -167.0  -165.0  -163.0  \
# lat
#  81.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  79.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  77.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  ...
# [86 rows x 180 columns]
# ```
#
# Go for it!

# %%
myTest = myTest.drop_duplicates()
table = myTest.pivot(index='lat',columns='lon',values='tempanomaly').sort_values('lat',axis=0,ascending=False)
print (table)
# Out:
# lon    -179.0  -177.0  -175.0  -173.0  -171.0  -169.0  -167.0  -165.0  -163.0  \
# lat
#  89.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  87.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  85.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  83.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  81.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  79.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  77.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  75.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  73.0    6.15    6.15    6.15    6.15    6.15     NaN     NaN     NaN     NaN
#  71.0    6.14    6.14    6.14    6.14    4.98    3.65    3.65    3.65    3.65
#  69.0    5.97    5.97    5.97    5.97    5.71    4.57    4.57    4.57    4.57
#  67.0    5.84    5.84    5.84    5.84    5.23    4.61    4.61    4.61    4.61
#  65.0    5.46    5.46    5.46    5.46    4.76    4.17    4.15    4.09    4.09
#  63.0     NaN     NaN     NaN     NaN    3.52    3.52    3.39    2.99    2.99
#  61.0     NaN     NaN     NaN     NaN    3.52    3.52    2.96    2.67    2.67
#  59.0     NaN     NaN    3.18    3.18    3.16    3.13    3.05    2.60    2.60
#  57.0     NaN     NaN    3.16    3.16    3.13    3.11    3.06    2.79    2.79
#  55.0     NaN     NaN    3.13    3.13    3.11    3.09    3.02    2.91    2.91
#  53.0     NaN     NaN     NaN     NaN     NaN     NaN    3.01    3.01    3.01
#  51.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  49.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  47.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  45.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  43.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  41.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  39.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  37.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  35.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  33.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  31.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# -31.0    1.05    1.05     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -33.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -35.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -37.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -39.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -41.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -43.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -45.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -47.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -49.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -51.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -53.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -55.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -57.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -59.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -61.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -63.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -65.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -67.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -69.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -71.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -73.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -75.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -77.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -79.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -81.0   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12
# -83.0   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12
# -85.0   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12
# -87.0   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12
# -89.0   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12
#
# lon    -161.0  ...   161.0   163.0   165.0   167.0   169.0   171.0   173.0  \
# lat            ...
#  89.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  87.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  85.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  83.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  81.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  79.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  77.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  75.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  73.0    2.53  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  71.0    2.94  ...    5.94    5.83    5.83    5.83    5.83    6.39    6.95
#  69.0    4.21  ...    5.07    5.21    5.21    5.21    5.21    6.16    7.10
#  67.0    3.45  ...    3.78    5.17    5.17    5.17    5.17    5.77    6.38
#  65.0    2.46  ...    3.09    4.63    4.63    4.68    4.69    5.14    5.59
#  63.0    2.22  ...     NaN    3.39    3.39    3.71    3.82    4.36    4.91
#  61.0    2.95  ...    1.35    3.45    3.45    3.17    3.08    3.18    3.27
#  59.0    2.37  ...    1.38    1.67    1.67    2.30    2.93    2.92    2.92
#  57.0    2.44  ...    0.94    0.88    0.88    1.27    1.50    1.50     NaN
#  55.0    2.80  ...    0.88    1.26    1.26    1.44    1.50    1.50     NaN
#  53.0    2.84  ...    1.10    1.50    1.50    1.50    1.50    1.50     NaN
#  51.0     NaN  ...    1.52     NaN     NaN     NaN     NaN     NaN     NaN
#  49.0     NaN  ...    1.76     NaN     NaN     NaN     NaN     NaN     NaN
#  47.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  45.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  43.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  41.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  39.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  37.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  35.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  33.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#  31.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...       ...  ...     ...     ...     ...     ...     ...     ...     ...
# -31.0     NaN  ...    0.70     NaN    0.12    0.12    0.12    0.12     NaN
# -33.0     NaN  ...    0.70     NaN     NaN     NaN     NaN    0.35    0.35
# -35.0     NaN  ...     NaN     NaN     NaN     NaN     NaN    0.40    0.40
# -37.0     NaN  ...     NaN     NaN     NaN     NaN     NaN    0.50    0.50
# -39.0     NaN  ...     NaN     NaN     NaN     NaN   -0.27    0.30    0.36
# -41.0     NaN  ...     NaN     NaN     NaN     NaN   -0.27   -0.02    0.24
# -43.0     NaN  ...     NaN     NaN     NaN     NaN    0.05    0.04    0.04
# -45.0     NaN  ...     NaN     NaN     NaN    0.41    0.31    0.25    0.18
# -47.0     NaN  ...     NaN     NaN     NaN    0.40    0.40    0.40    0.24
# -49.0     NaN  ...     NaN     NaN     NaN    0.66    0.66    0.66     NaN
# -51.0     NaN  ...     NaN     NaN     NaN    1.49    1.49    1.49     NaN
# -53.0     NaN  ...    1.35     NaN     NaN    1.65    1.65    1.65     NaN
# -55.0     NaN  ...    1.35     NaN     NaN    1.65    1.65    1.65     NaN
# -57.0     NaN  ...    1.35     NaN     NaN     NaN     NaN     NaN     NaN
# -59.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -61.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -63.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -65.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -67.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -69.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -71.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -73.0     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# -75.0     NaN  ...    0.08   -0.81   -0.81   -0.81   -0.81   -0.44   -0.06
# -77.0     NaN  ...    0.08   -0.81   -0.81   -0.81   -0.81   -0.44   -0.06
# -79.0     NaN  ...    0.08   -0.27   -0.27   -0.27   -0.27   -0.22   -0.06
# -81.0   -3.12  ...   -3.12   -0.21   -0.21   -0.21   -0.21   -0.34   -3.12
# -83.0   -3.12  ...   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12
# -85.0   -3.12  ...   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12
# -87.0   -3.12  ...   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12
# -89.0   -3.12  ...   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12   -3.12
#
# lon     175.0   177.0   179.0
# lat
#  89.0     NaN     NaN     NaN
#  87.0     NaN     NaN     NaN
#  85.0     NaN     NaN     NaN
#  83.0     NaN     NaN     NaN
#  81.0     NaN     NaN     NaN
#  79.0     NaN     NaN     NaN
#  77.0     NaN     NaN     NaN
#  75.0     NaN     NaN     NaN
#  73.0     NaN     NaN     NaN
#  71.0    6.95    6.95    6.95
#  69.0    7.10    7.10    7.10
#  67.0    6.38    6.38    6.38
#  65.0    5.62    5.71    5.71
#  63.0    5.11    5.72    5.72
#  61.0    3.40    5.72    5.72
#  59.0    2.92     NaN     NaN
#  57.0     NaN     NaN     NaN
#  55.0     NaN     NaN     NaN
#  53.0     NaN     NaN     NaN
#  51.0     NaN     NaN     NaN
#  49.0     NaN     NaN     NaN
#  47.0     NaN     NaN     NaN
#  45.0     NaN     NaN     NaN
#  43.0     NaN     NaN     NaN
#  41.0     NaN     NaN     NaN
#  39.0     NaN     NaN     NaN
#  37.0     NaN     NaN     NaN
#  35.0     NaN     NaN     NaN
#  33.0     NaN     NaN     NaN
#  31.0     NaN     NaN     NaN
# ...       ...     ...     ...
# -31.0     NaN     NaN     NaN
# -33.0    0.35    0.35     NaN
# -35.0    0.46    0.47    0.50
# -37.0    0.70    0.60    0.50
# -39.0    0.51    0.51    0.50
# -41.0    0.39    0.39     NaN
# -43.0    0.14    0.14     NaN
# -45.0    0.20    0.14     NaN
# -47.0    0.24     NaN     NaN
# -49.0     NaN     NaN     NaN
# -51.0     NaN     NaN     NaN
# -53.0     NaN     NaN     NaN
# -55.0     NaN     NaN     NaN
# -57.0     NaN     NaN     NaN
# -59.0     NaN     NaN     NaN
# -61.0     NaN     NaN     NaN
# -63.0     NaN     NaN     NaN
# -65.0     NaN     NaN     NaN
# -67.0     NaN     NaN     NaN
# -69.0     NaN     NaN     NaN
# -71.0     NaN     NaN     NaN
# -73.0     NaN     NaN     NaN
# -75.0   -0.06   -0.06   -0.06
# -77.0   -0.06   -0.06   -0.06
# -79.0   -0.06   -0.06   -0.06
# -81.0   -3.12   -3.12   -3.12
# -83.0   -3.12   -3.12   -3.12
# -85.0   -3.12   -3.12   -3.12
# -87.0   -3.12   -3.12   -3.12
# -89.0   -3.12   -3.12   -3.12
#
# [90 rows x 180 columns]

# %% [markdown]
# If your data looks like the 86x180 2-d example above, then go ahead and run this next cell.  You'll need to change the globaltemps, of course, to whatever your dataset is called.  If you chocse "2018-11-15" as your date, your output should look like this:
#
# ![weather](img/weather.png)

# %%
sns.heatmap(data=table, center=0, cmap="bwr");

# %% [markdown]
# This plot looks vaguely like a world map, because this dataset only has values for land.

# %% [markdown]
# Congrats, you're done.  I was asked for warm weather, and I think this dataset delivers.
